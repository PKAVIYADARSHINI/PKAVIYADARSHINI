# %% [markdown]
# <a href="https://colab.research.google.com/github/PKAVIYADARSHINI/PKAVIYADARSHINI/blob/main/Fake_News_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **kavi project**<div style="padding:20px;
#             color:#150d0a;
#             margin:10px;
#             font-size:300%;
#             text-align:center;
#             display:fill;
#             border-radius:20px;
#             border-width: 5px;
#             border-style: solid;
#             border-color: #150d0a;
#             background-color:#7393B3;
#             overflow:hidden;
#             font-weight:500">Fake News Detection</div>

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load and View Datasets

# %%
fake = pd.read_csv('/content/True.csv (1).zip')
true = pd.read_csv('/content/fake-news-detection.ipynb')

# %%
fake.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.shape
# Out:
# (21417, 4)

# %%
true.head()
# Out:
# Empty DataFrame
# ...

# %%
true.shape
# Out:
# (0, 295)

# %% [markdown]
# ## Add indicator of true or fake

# %%
fake['is_true'] = 0
true['is_true'] = 1

# %%
fake.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  is_true
# 0  December 31, 2017         0
# 1  December 29, 2017         0
# 2  December 31, 2017         0
# 3  December 30, 2017         0
# 4  December 29, 2017         0

# %%
true.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## Combine Datasets

# %%
df = pd.concat([fake, true], axis = 0)
df.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %% [markdown]
# ## Visualisations

# %%
import seaborn as sns
sns.countplot(x = df["is_true"], palette = "Blues")
# Out:
# <ipython-input-16-04afb0819a14>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df["is_true"], palette = "Blues")
# <Axes: xlabel='is_true', ylabel='count'>

# %% [markdown]
# ## Clean Text Strings

# %%
import re
import string
def wp(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df["text"] = df["text"].apply(wp)

# %% [markdown]
# ## Prepare Data for Modeling

# %%
x = df["text"]
y = df["is_true"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
del x, y, true, fake

# %% [markdown]
# ## Run two models and compare results

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(xv_train,y_train)

pred_lr = lr.predict(xv_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, pred_lr))

from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred_lr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7ce2ba4c10bd> in <cell line: 4>()
#       2
#       3 lr = LogisticRegression()
# ----> 4 lr.fit(xv_train,y_train)
#       5
#       6 pred_lr = lr.predict(xv_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1239         classes_ = self.classes_
#    1240         if n_classes < 2:
# -> 1241             raise ValueError(
#    1242                 "This solver needs samples of at least 2 classes"
#    1243                 " in the data, but the data contains only one"
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf.fit(xv_train,y_train)

pred_clf = clf.predict(xv_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, pred_clf))

from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5355
#
#     accuracy                           1.00      5355
#    macro avg       1.00      1.00      1.00      5355
# weighted avg       1.00      1.00      1.00      5355
# 1.0
